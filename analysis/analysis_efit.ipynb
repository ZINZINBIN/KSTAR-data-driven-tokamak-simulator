# %%
import numpy as np

if __name__ == "__main__":
    filename = "../dataset/PF_data/g019815_000390.npz"
    efit = np.load(filename)

# %%
import matplotlib.pyplot as plt

plt.contourf(efit['R'], efit['Z'], efit['psi'])
plt.plot(efit['rzbdys'][:,0], efit['rzbdys'][:,1], 'r')

# %%
efit['psi_a']
# Out:
# array(-0.39509451)
